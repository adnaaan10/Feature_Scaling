# %% [markdown]
# <a href="https://colab.research.google.com/github/adnaaan10/Feature_Scaling/blob/main/FeatureScaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Social_Network_Ads (1).csv')
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %% [markdown]
# # **Standardization**

# %%
df=df.iloc[:,2:]

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 241   38            59000          0
# 261   36           144000          1
# 10    26            80000          0
# 196   30            79000          0
# 102   32            86000          0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(df.drop('Purchased',axis=1),df['Purchased'],test_size=0.1,random_state=1)

# %%
X_train.shape
# Out:
# (360, 2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar=StandardScaler()
scalar.fit(X_train)
X_train_scalar=scalar.transform(X_train)
X_test_scalar=scalar.transform(X_test)

# %%
X_train
# Out:
#      Age  EstimatedSalary
# 268   47           144000
# 204   58           101000
# 171   34           115000
# 62    23            66000
# 385   56            60000
# ..   ...              ...
# 255   52            90000
# 72    20            23000
# 396   51            23000
# 235   46            79000
# 37    30            49000
#
# [360 rows x 2 columns]

# %%
X_train_scalar
# Out:
# array([[ 0.93332973,  2.2053375 ],
#        [ 2.00868199,  0.93544112],
#        [-0.33754113,  1.34889575],
#        [-1.41289339, -0.09819548],
#        [ 1.8131634 , -0.27539032],
#        [-0.63081902,  1.43749318],
#        [ 1.03108903, -1.01370217],
#        [ 0.93332973,  1.2898308 ],
#        [ 0.15125536,  0.28572669],
#        [ 1.42212621, -0.92510475],
#        [-1.31513409, -0.33445527],
#        [-0.04426324, -0.48211764],
#        [ 0.44453325,  0.31525916],
#        [ 0.83557043, -1.22042949],
#        [ 0.44453325,  0.10853184],
#        [-0.04426324, -0.21632537],
#        [ 2.20420058, -0.80697485],
#        [-0.14202253, -0.51165011],
#        [ 2.00868199,  0.75824627],
#        [ 0.54229254,  1.76235039],
#        [-1.0218562 ,  0.58105143],
#        [-1.41289339,  0.37432411],
#        [ 0.05349606,  1.26029833],
#        [-0.23978183, -0.57071506],
#        [-0.14202253,  0.87637617],
#        [-0.04426324,  2.2053375 ],
#        [-1.1196155 , -1.01370217],
# ...

# %%
X_test_scalar=pd.DataFrame(X_test_scalar,columns=X_train.columns)
X_train_scalar=pd.DataFrame(X_train_scalar,columns=X_test.columns)

# %%
X_test_scalar
# Out:
#          Age  EstimatedSalary
# 0  -0.142023        -1.072767
# 1   0.151255        -0.245858
# 2  -0.142023         1.437493
# 3   0.151255         1.555623
# 4  -1.119615         1.437493
# 5   0.053496        -0.127728
# 6  -1.706171        -0.984170
# 7   1.128848         0.581051
# 8  -0.630819        -1.515754
# 9   1.031089         2.116740
# 10 -0.337541         0.078999
# 11  0.151255         0.108532
# 12 -0.239782         0.078999
# 13  1.031089         1.821415
# 14  1.519886         0.374324
# 15  1.813163         1.880480
# 16  2.204201         0.403857
# 17 -1.021856        -0.334455
# 18 -0.924097         0.521986
# 19  2.204201         0.964974
# 20  0.249015         0.167597
# 21  1.226608         0.551519
# 22  0.640052         2.057675
# 23  0.933330        -0.777442
# 24  0.737811        -1.279494
# 25 -1.119615        -1.604352
# 26  2.008682        -0.659312
# 27  1.128848         0.138064
# 28  1.519886        -1.043235
# 29  1.422126         1.319363
# ...

# %%
X_train_scalar
# Out:
#           Age  EstimatedSalary
# 0    0.933330         2.205338
# 1    2.008682         0.935441
# 2   -0.337541         1.348896
# 3   -1.412893        -0.098195
# 4    1.813163        -0.275390
# ..        ...              ...
# 355  1.422126         0.610584
# 356 -1.706171        -1.368092
# 357  1.324367        -1.368092
# 358  0.835570         0.285727
# 359 -0.728578        -0.600248
#
# [360 rows x 2 columns]

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,6))
ax1.scatter(X_train['Age'],X_train['EstimatedSalary'])
ax1.set_title('Before Scaling')
ax2.scatter(X_train_scalar['Age'],X_train_scalar['EstimatedSalary'])
ax2.set_title('After Scaling')
# Out:
# Text(0.5, 1.0, 'After Scaling')

# %%
fig,(ax1,ax2,ax3,ax4)=plt.subplots(ncols=4,figsize=(12,6))
# Pass the DataFrame and specify 'x' and 'y' columns for kdeplot
sns.kdeplot(x=X_train['Age'], ax=ax1) # Specify ax=ax1 to plot on the first subplot
ax1.set_title(' Age Before Scaling')
sns.kdeplot(x=X_train_scalar['Age'], ax=ax2) # Specify ax=ax2 to plot on the second subplot
ax2.set_title('Age After Scaling')
sns.kdeplot(x=X_train['EstimatedSalary'], ax=ax3) # Specify ax=ax3 to plot on the third subplot
ax3.set_title('EstimatedSalary Before Scaling')
sns.kdeplot(x=X_train_scalar['EstimatedSalary'], ax=ax4) # Specify ax=ax4 to plot on the fourth subplot
ax4.set_title('EstimatedSalary After Scaling')
# Out:
# Text(0.5, 1.0, 'EstimatedSalary After Scaling')

# %% [markdown]
# # **Normalization**

# %%
df=pd.read_csv('/content/wine_data.csv',header=None,usecols=[0,1,2])
df.columns=['Class label','Alcohol','Malic acid']

# %%
df
# Out:
#      Class label  Alcohol  Malic acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.kdeplot(x=df['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(x=df['Malic acid'])
# Out:
# <Axes: xlabel='Malic acid', ylabel='Density'>

# %%
sns.scatterplot(x=df['Alcohol'],y=df['Malic acid'],hue=df['Class label'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic acid'>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(df.drop('Class label',axis=1),df['Class label'],test_size=0.1,random_state=1)

# %%
X_train.shape
# Out:
# (160, 2)

# %%
X_test.shape
# Out:
# (18, 2)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax=MinMaxScaler()

# %%
minmax.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train_scaled=minmax.transform(X_train)
X_test_scaled=minmax.transform(X_test)

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,6))
ax1.scatter(X_train['Alcohol'],X_train['Malic acid'])
ax1.set_title('Before Scaling')
# Access the columns of the scaled data using numerical indices
ax2.scatter(X_train_scaled[:, 0], X_train_scaled[:, 1])  # Assuming 'Alcohol' is column 0 and 'Malic acid' is column 1
ax2.set_title('After Scaling')
plt.show() # This line was missing in your original code, adding for display

# %%
#we can convert numpy array to dataframe
X_train_scaled=pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_test_scaled=pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(12,6))
ax1.scatter(X_train['Alcohol'],X_train['Malic acid'])
ax1.set_title('Before Scaling')
ax2.scatter(X_train_scaled['Alcohol'],X_train_scaled['Malic acid'])
ax2.set_title('After Scaling')
# Out:
# Text(0.5, 1.0, 'After Scaling')
